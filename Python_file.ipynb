# %%
# %%capture
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
adult = fetch_ucirepo(id=2)

# data (as pandas dataframes)
X = adult.data.features
y = adult.data.targets

# metadata
print(adult.metadata)

# variable information
print(adult.variables)
# Out:
# {'uci_id': 2, 'name': 'Adult', 'repository_url': 'https://archive.ics.uci.edu/dataset/2/adult', 'data_url': 'https://archive.ics.uci.edu/static/public/2/data.csv', 'abstract': 'Predict whether income exceeds $50K/yr based on census data. Also known as "Census Income" dataset. ', 'area': 'Social Science', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 48842, 'num_features': 14, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Income', 'Education Level', 'Other', 'Race', 'Sex'], 'target_col': ['income'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1996, 'last_updated': 'Mon Sep 09 2024', 'dataset_doi': '10.24432/C5XW20', 'creators': ['Barry Becker', 'Ronny Kohavi'], 'intro_paper': None, 'additional_info': {'summary': 'Extraction was done by Barry Becker from the 1994 Census database.  A set of reasonably clean records was extracted using the following conditions: ((A
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(X)
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country
# 0          2174             0              40  United-States
# ...

# %%
df1 = pd.DataFrame(y)
df1
# Out:
#        income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 48837  <=50K.
# 48838  <=50K.
# 48839  <=50K.
# 48840  <=50K.
# 48841   >50K.
#
# [48842 rows x 1 columns]

# %%
df1['income'].value_counts()
# Out:
# income
# <=50K     24720
# <=50K.    12435
# >50K       7841
# >50K.      3846
# Name: count, dtype: int64

# %%
df['income'] = df1['income']
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.isna().sum()
# Out:
# age                 0
# workclass         963
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# ?                    1836
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df['workclass'] = df['workclass'].replace('?', 'Other')

# %%
df['workclass'].fillna('Private', inplace = True)

# %%
df.isna().sum()
# Out:
# age                 0
# workclass           0
# fnlwgt              0
# education           0
# education-num       0
# marital-status      0
# occupation        966
# relationship        0
# race                0
# sex                 0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country    274
# income              0
# dtype: int64

# %%
df['occupation'].value_counts()
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Other                1843
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
df['occupation'] = df['occupation'].replace('?', 'Other')

# %%
df['occupation'].fillna('Prof-specialty', inplace = True)

# %%
df['native-country'].value_counts()
# Out:
# native-country
# United-States                 43832
# Mexico                          951
# ?                               583
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# ...

# %%
df['native-country'] = df['native-country'].replace('?', 'other')

# %%
df['native-country'].fillna('United-States',inplace = True)

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %%
df['income'].value_counts()
# Out:
# income
# <=50K     24720
# <=50K.    12435
# >50K       7841
# >50K.      3846
# Name: count, dtype: int64

# %%
df['income'] = df['income'].replace('<=50K.','<=50K')
df['income'] = df['income'].replace('>50K.','>50K')

# %%
df['IncomeBracket'] = df['income'].apply(lambda x: 1 if x == '>50K' else 0)

# %%
df
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64           Private  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital-status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# ...

# %%
df['workclass_occpation'] = df['workclass'] + '_' + df['occupation']

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
avg_age_per_workclass = df.groupby('workclass')['age'].mean()
avg_age_per_workclass
# Out:
# workclass
# Federal-gov         42.577514
# Local-gov           41.676020
# Never-worked        19.900000
# Other               40.960240
# Private             36.949439
# Self-emp-inc        45.799410
# Self-emp-not-inc    45.332470
# State-gov           39.512367
# Without-pay         47.285714
# Name: age, dtype: float64

# %%
proportion_over_50k_per_education = df[df['IncomeBracket'] == 1].groupby('education').size() / df.groupby('education').size()
proportion_over_50k_per_education
# Out:
# education
# 10th            0.062635
# 11th            0.050773
# 12th            0.073059
# 1st-4th         0.032389
# 5th-6th         0.053045
# 7th-8th         0.064921
# 9th             0.054233
# Assoc-acdm      0.257964
# Assoc-voc       0.253275
# Bachelors       0.412835
# Doctorate       0.725589
# HS-grad         0.158578
# Masters         0.549116
# Preschool       0.012048
# Prof-school     0.739808
# Some-college    0.189649
# dtype: float64

# %%
df.to_csv('adult_cleaned.csv', index=False)

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income  \
# 0          2174             0              40  United-States  <=50K
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(30,6))
sns.lineplot(x=df['education'],y=df['income'])
plt.xlabel('education')
plt.ylabel('Income Bracket')
plt.xticks(rotation= 90)
plt.title('education vs Income Bracket')
plt.show()
#

# %%
columns = ['age','education-num', 'capital-gain', 'capital-loss', 'hours-per-week', 'IncomeBracket']
correlation_matrix = df[columns].corr()
correlation_matrix
# Out:
#                      age  education-num  capital-gain  capital-loss  \
# age             1.000000       0.030940      0.077229      0.056944
# education-num   0.030940       1.000000      0.125146      0.080972
# capital-gain    0.077229       0.125146      1.000000     -0.031441
# capital-loss    0.056944       0.080972     -0.031441      1.000000
# hours-per-week  0.071558       0.143689      0.082157      0.054467
# IncomeBracket   0.230369       0.332613      0.223013      0.147554
#
#                 hours-per-week  IncomeBracket
# age                   0.071558       0.230369
# education-num         0.143689       0.332613
# capital-gain          0.082157       0.223013
# capital-loss          0.054467       0.147554
# hours-per-week        1.000000       0.227687
# IncomeBracket         0.227687       1.000000

# %%
#columns = ['age','education-num', 'capital-gain', 'capital-loss', 'hours-per-week', 'IncomeBracket']
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)

plt.show()
